# %% [markdown]
# # Cubic Spline Timeseries Plots

# %% [markdown]
# ## Lake Geneva

# %%
import sys
import os
sys.path.append('../scripts/')
from visualization import PhenologyVisualization
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd
import seaborn as sns
import netCDF4
from datetime import datetime
import matplotlib.dates as mdates
import colorcet as cc
from matplotlib.colors import ListedColormap

# %%
lakeid = 327
i , j = 23, 30

# %%
pc_phenology_path_v3 = f"C:\\Users\sparksno\Desktop\data_Phenology\\data\\v3.1\\phenology\\phycocyanin\\{lakeid}.nc"
pc_extract_path_v3 = f"C:\\Users\sparksno\Desktop\data_Phenology\\data\\v3.1\\extract\\phycocyanin\\{lakeid}.nc"

chl_phenology_path_v3 = f"C:\\Users\sparksno\Desktop\data_Phenology\\data\\v3.1\\phenology\\chla\\{lakeid}.nc"
chl_extract_path_v3 = f"C:\\Users\sparksno\Desktop\data_Phenology\\data\\v3.1\\extract\\chla\\{lakeid}.nc"

chl_phenology_path_v2 = f"C:\\Users\sparksno\Desktop\data_Phenology\\data\\v2.1\\phenology\\chla_mean\\{lakeid}.nc"
chl_extract_path_v2 = f"C:\\Users\sparksno\Desktop\data_Phenology\\data\\v2.1\\extract\\chla_mean\\{lakeid}.nc"
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\sparksno\AppData\Local\Temp\ipykernel_27984\2431509738.py:1: SyntaxWarning: invalid escape sequence '\s'
#   pc_phenology_path_v3 = f"C:\\Users\sparksno\Desktop\data_Phenology\\data\\v3.1\\phenology\\phycocyanin\\{lakeid}.nc"
# C:\Users\sparksno\AppData\Local\Temp\ipykernel_27984\2431509738.py:2: SyntaxWarning: invalid escape sequence '\s'
#   pc_extract_path_v3 = f"C:\\Users\sparksno\Desktop\data_Phenology\\data\\v3.1\\extract\\phycocyanin\\{lakeid}.nc"
# C:\Users\sparksno\AppData\Local\Temp\ipykernel_27984\2431509738.py:4: SyntaxWarning: invalid escape sequence '\s'
#   chl_phenology_path_v3 = f"C:\\Users\sparksno\Desktop\data_Phenology\\data\\v3.1\\phenology\\chla\\{lakeid}.nc"
# C:\Users\sparksno\AppData\Local\Temp\ipykernel_27984\2431509738.py:5: SyntaxWarning: invalid escape sequence '\s'
#   chl_extract_path_v3 = f"C:\\Users\sparksno\Desktop\data_Phenology\\data\\v3.1\\extract\\chla\\{lakeid}.nc"
# C:\Users\sparksno\AppData\Local\Temp\ipykernel_27984\2431509738.py:7: SyntaxWarning: invalid escape sequence '\s'
#   chl_phenology_path_v2 = f"C:\\Users\sparksno\Desktop\data_Phenology\\data\\v2.1\\phenology\\chla_mean\\{lakeid}.nc"
# C:\Users\sparksno\AppData\Local\Temp\ipykernel_27984\2431509738.py:8: SyntaxWarning: invalid escape sequence '\s'
#   chl_extract_path_v2 = f"C:\\Users\sparksno\Desktop\data_Phenology\\data\\v2.1\\extract\\chla_mean\\{lakeid}.nc"

# %%
PhenologyVisualization.set_shapefile_path(r"C:\Users\sparksno\Desktop\data_Phenology\shapefile\lakescci_v2.1.0_data-availability.shp")

# %%
# load classes
phyco_v3 = PhenologyVisualization(pc_extract_path_v3, pc_phenology_path_v3)
chla_v3 = PhenologyVisualization(chl_extract_path_v3, chl_phenology_path_v3)
chla_v2 = PhenologyVisualization(chl_extract_path_v2, chl_phenology_path_v2)

# %%
# Implement a time series plot of the cubic spline and background data
# %matplotlib inline

fig, ax = plt.subplots(1,1,figsize=(15,5))

chla_v2.single_plot(i,j, ax, aggregation=False,start=2003, end= 2012)
# Out:
# c:\Users\sparksno\Documents\GitHub\phenology_visualization\notebooks\../scripts\functions_plotting.py:396: Warning: Negative Troughs(s) in time period 2003-2012
#   warnings.warn(f"Negative Troughs(s) in time period {start}-{end}", Warning)

# %%
# Implement a split plot with formatting edits after creation.
fig, axs = plt.subplots(1,2, figsize = (20,8))

chla_v3.split_plot(ax0 = axs[0], ax1=axs[1],latitude_idx = i,longitude_idx = j, aggregation=False,end0 = 2012,start1 = 2016)
axs[0].set_title("")
axs[1].set_title("")
# axs[0].set_ylim(0,2)
# axs[1].set_ylim(0,2)


axs[0].texts[0].set_fontsize(12)
axs[1].texts[0].set_fontsize(12)

# %%
# Plot the splines and data from two pixels on the same plot, with formatting edits.
fig, ax = plt.subplots(1,1,figsize=(15,5))

chla_v3.single_plot(i,j, ax, aggregation=False,start=2003, end= 2012)
ax.collections[0].set(color = 'steelblue')
ax.collections[0].set_sizes([30])
chla_v3.single_plot(16,57, ax, aggregation=False, start=2003,end= 2012)
ax.collections[-5].set(color = 'orangered',sizes=[30])
for txt in ax.texts:
    txt.remove()
ax.get_legend().remove()
ax.set_ylim(0,27.5)
ax.set_title("")
ax.grid()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 7
#       5 ax.collections[0].set(color = 'steelblue')
#       6 ax.collections[0].set_sizes([30])
# ----> 7 chla_v3.single_plot(16,57, ax, aggregation=False, start=2003,end= 2012)
#       8 ax.collections[-5].set(color = 'orangered',sizes=[30])
#       9 for txt in ax.texts:
#
# File c:\Users\sparksno\Documents\GitHub\phenology_visualization\notebooks\../scripts\visualization.py:2164, in PhenologyVisualization.single_plot(self, latitude_idx, longitude_idx, ax, aggregation, start, end, annotation)
#    2161 lon_val = float(lon[longitude_idx])
#    2162 smoothing = pixel_data["smoothing"]
# -> 2164 plotting_data = grab_plotting_variables(start = start, end = end, pixel_data=pixel_data, variables=["pks", "trgs", "midUP", "midDOWN"])
#    2166 mask     = (pixel_data["values"] != -9999) & (pixel_data["qa"] == 0)
#    2167 values_m = pixel_data["values"][mask]
#
# File c:\Users\sparksno\Documents\GitHub\phenology_visualization\notebooks\../scripts\functions_plotting.py:203, in grab_plotting_variables(start, end, pixel_data, variables)
#     200     continue
#     202 date_mask = np.array([(d.year <= end) & (d.year >= start) for d in pixel_data[var_x]])
# --> 203 var_x_sub    = pixel_data[var_x][date_mask]
#     204 var_y_sub    = pixel_data[var_y][date_mask]
#     205 if var in ["pks","trgs"]:
#
# IndexError: arrays used as indices must be of integer (or boolean) type

# %%
# Compare single years
years = [2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023]

chla_v3.single_years_plot(i, j, years = years, ncol = 5, nrow = 5, annotation = ["R2", "RMSE"], ylim = (-0.5,6))
# Out:
# c:\Users\sparksno\Documents\GitHub\phenology_visualization\notebooks\../scripts\visualization.py:2105: UserWarning: No peaks/troughs available for 2003-2003; using automatic y-limits.
#   warnings.warn(
# c:\Users\sparksno\Documents\GitHub\phenology_visualization\notebooks\../scripts\visualization.py:2105: UserWarning: No peaks/troughs available for 2012-2012; using automatic y-limits.
#   warnings.warn(
# c:\Users\sparksno\Documents\GitHub\phenology_visualization\notebooks\../scripts\visualization.py:2105: UserWarning: No peaks/troughs available for 2014-2014; using automatic y-limits.
#   warnings.warn(

# %%
# plot multiple years in the same plot
fig, ax = plt.subplots(1,1, figsize = (15,7))

chla_v3.yearly_cubic_spline(ax, i,j)
ax.set_ylim(-5,30)
# Out:
# c:\Users\sparksno\Documents\GitHub\phenology_visualization\notebooks\../scripts\visualization.py:2628: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(to_frac_month(trgs_x_sub[tm]), trgs_y_sub[tm], color="darkgray", s=50,
# c:\Users\sparksno\Documents\GitHub\phenology_visualization\notebooks\../scripts\visualization.py:2624: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(to_frac_month(pks_x_sub[pm]), pks_y_sub[pm], color="black", s=50,
# c:\Users\sparksno\Documents\GitHub\phenology_visualization\notebooks\../scripts\visualization.py:2632: UserWarning: Not enough data to plot for year 2024
#   warnings.warn(f"Not enough data to plot for year {year}")
# (-5.0, 30.0)
