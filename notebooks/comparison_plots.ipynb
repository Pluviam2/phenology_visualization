# %% [markdown]
# # Comparison Plots

# %%
## Lake Huron

# %%
import sys
import os
sys.path.append('../scripts/')
from visualization import PhenologyVisualization
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd
import seaborn as sns
import netCDF4
from datetime import datetime
import matplotlib.dates as mdates
import colorcet as cc
from matplotlib.colors import ListedColormap

# %%
lakeid = 5
i , j = 31, 94

# %%
pc_phenology_path_v3 = f"C:\\Users\sparksno\Desktop\data_Phenology\\data\\v3.1\\phenology\\phycocyanin\\{lakeid}.nc"
pc_extract_path_v3 = f"C:\\Users\sparksno\Desktop\data_Phenology\\data\\v3.1\\extract\\phycocyanin\\{lakeid}.nc"

chl_phenology_path_v3 = f"C:\\Users\sparksno\Desktop\data_Phenology\\data\\v3.1\\phenology\\chla\\{lakeid}.nc"
chl_extract_path_v3 = f"C:\\Users\sparksno\Desktop\data_Phenology\\data\\v3.1\\extract\\chla\\{lakeid}.nc"

chl_phenology_path_v2 = f"C:\\Users\sparksno\Desktop\data_Phenology\\data\\v2.1\\phenology\\chla_mean\\{lakeid}.nc"
chl_extract_path_v2 = f"C:\\Users\sparksno\Desktop\data_Phenology\\data\\v2.1\\extract\\chla_mean\\{lakeid}.nc"
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\s'
# <>:7: SyntaxWarning: invalid escape sequence '\s'
# <>:8: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\sparksno\AppData\Local\Temp\ipykernel_13704\2431509738.py:1: SyntaxWarning: invalid escape sequence '\s'
#   pc_phenology_path_v3 = f"C:\\Users\sparksno\Desktop\data_Phenology\\data\\v3.1\\phenology\\phycocyanin\\{lakeid}.nc"
# C:\Users\sparksno\AppData\Local\Temp\ipykernel_13704\2431509738.py:2: SyntaxWarning: invalid escape sequence '\s'
#   pc_extract_path_v3 = f"C:\\Users\sparksno\Desktop\data_Phenology\\data\\v3.1\\extract\\phycocyanin\\{lakeid}.nc"
# C:\Users\sparksno\AppData\Local\Temp\ipykernel_13704\2431509738.py:4: SyntaxWarning: invalid escape sequence '\s'
#   chl_phenology_path_v3 = f"C:\\Users\sparksno\Desktop\data_Phenology\\data\\v3.1\\phenology\\chla\\{lakeid}.nc"
# C:\Users\sparksno\AppData\Local\Temp\ipykernel_13704\2431509738.py:5: SyntaxWarning: invalid escape sequence '\s'
#   chl_extract_path_v3 = f"C:\\Users\sparksno\Desktop\data_Phenology\\data\\v3.1\\extract\\chla\\{lakeid}.nc"
# C:\Users\sparksno\AppData\Local\Temp\ipykernel_13704\2431509738.py:7: SyntaxWarning: invalid escape sequence '\s'
#   chl_phenology_path_v2 = f"C:\\Users\sparksno\Desktop\data_Phenology\\data\\v2.1\\phenology\\chla_mean\\{lakeid}.nc"
# C:\Users\sparksno\AppData\Local\Temp\ipykernel_13704\2431509738.py:8: SyntaxWarning: invalid escape sequence '\s'
#   chl_extract_path_v2 = f"C:\\Users\sparksno\Desktop\data_Phenology\\data\\v2.1\\extract\\chla_mean\\{lakeid}.nc"

# %%
PhenologyVisualization.set_shapefile_path(r"C:\Users\sparksno\Desktop\data_Phenology\shapefile\lakescci_v2.1.0_data-availability.shp")

# %%
# load classes
phyco_v3 = PhenologyVisualization(pc_extract_path_v3, pc_phenology_path_v3)
chla_v3 = PhenologyVisualization(chl_extract_path_v3, chl_phenology_path_v3)
chla_v2 = PhenologyVisualization(chl_extract_path_v2, chl_phenology_path_v2)

# %% [markdown]
# ## Between Phenology Variables

# %%
# %matplotlib inline

fig, ax = plt.subplots(1,1,figsize=(15,5))
phyco_v3.extrema_comparison(chla_v3, i,j, ax)
# Out:
# c:\Users\sparksno\Documents\GitHub\phenology_visualization\notebooks\../scripts\visualization.py:1417: UserWarning: You passed a edgecolor/edgecolors ('blue') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(
# c:\Users\sparksno\Documents\GitHub\phenology_visualization\notebooks\../scripts\visualization.py:1417: UserWarning: You passed a edgecolor/edgecolors ('green') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(

# %%
fig, ax = plt.subplots(1,1,figsize=(15,5))
chla_v3.extrema_comparison(chla_v2, i,j, ax, purple_chla21=True)
ax.set_title("")
# Out:
# c:\Users\sparksno\Documents\GitHub\phenology_visualization\notebooks\../scripts\visualization.py:1417: UserWarning: You passed a edgecolor/edgecolors ('purple') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(
# Text(0.5, 1.0, '')
